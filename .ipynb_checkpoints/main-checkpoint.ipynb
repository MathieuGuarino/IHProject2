# %% [markdown]
# Context https://www.kaggle.com/seraphimstreets/environmentequity-starterpack
#
# Climate change refers to both global warming driven by human emission of greenhouse gases, as well as the rise in environmental disasters induced by said warming. For the past few decades, this issue has been a plague on the conscious of humanity, as it grapples over how to handle this existential threat. On one hand, the scientific community is frustrated by the lack of initiative by governments to curb fossil fuel emissions and widespread mortality, which is projected to happen by the end of the century. On the other, policymakers have to strike a precarious balance between meeting short-term needs, such as ensuring annual economic growth and low unemployment, as well as long-term planning against the effects of climate change, through measures such as renewable energy investment and reforestation.
#
# Climate change policies, unfortunately, often do not lend themselves to immediate economic advantage, and in fact usually have significant costs associated with them. For instance, renewable energies require a sizable initial investment to reach scale, and have only recently become competitive with fossil fuel production costs. Another point of contention for climate change policies are the inequities associated with them. In my opinion, these can be broadly surmised into two questions, namely:
#
# 1) How can we ensure that the positive impact of climate change measures will affect all demographics, especially the most vulnerable?
#
# 2) How do we prevent the economic drawbacks of climate change policies from harming those from lower socio-economic groups?
#
# For question 2, for instance, a national shift from fossil fuel to renewable energy sources may hurt the manufacturing sector, which could result in the loss of many blue-collar jobs.
# Content
#
# This compendium contains datasets collected and scraped from the Organization of Economic Co-Operation and Development (OECD), BP Statistical Review of World Energy, International Renewable Energy Agency (IRENA), Berkeley Earth, Institute for Health Metrics and Evaluation (IMHE), Our World In Data. These are just the datasets that I personally think would be most useful for the CDP Analytics competition. If anyone has any suggestions for other datasets which may be useful, I would be happy to add them in .
#
# The folder structure is as follows:
#
# ├── Corporations
# ├── Social Equity
# │ ├── Energy
# │ ├── Equity indicators
# │ ├── Government policies and support
# │ ├── Pollution
# │ │ ├── Health and Deaths
# │ ├── Vulnerability
# └── readme.txt
#
# I've split the datasets into folders based on topic and relevance to certain stakeholders. The datasets and their features should be quite self-explanatory, so I won't go into it here. However, there is a attached readme which briefly describes each dataset and provides individual acknowledgements.
# Acknowledgements
#
# This compendium contains datasets collected and scraped from the Organization of Economic Co-Operation and Development (OECD), BP Statistical Review of World Energy, International Renewable Energy Agency (IRENA), Berkeley Earth, ClimateWatch, Institute for Health Metrics and Evaluation (IMHE), Our World In Data, Corporate Knights, World Resource Institute. Huge thanks to these organizations for providing these thoroughly researched, reliable and open-source datasets.
#
# OECD: https://stats.oecd.org/
#
# Our World in Data: https://ourworldindata.org/co2-and-other-greenhouse-gas-emissions, https://ourworldindata.org/energy https://ourworldindata.org/co2-and-other-greenhouse-gas-emissions
#
# ClimateWatch: https://www.climatewatchdata.org/
#
# Corporate Knights: https://www.corporateknights.com/reports/2020-global-100/2020-global-100-ranking-15795648/
#
# IRENA: https://www.irena.org/Statistics/View-Data-by-Topic/Costs/Global-Trends
#
# Institute for Health Metrics and Evaluation: http://www.healthdata.org/
#
# BP Statistical Review of World Energy: https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html
#
# World Resource Institute: https://www.wri.org/

# %% [markdown]
# # Is there a link between how a country consume energy and health ?
# # How is this behavior over the years ?

# %%
# Importing libraries
import matplotlib.pyplot as plt # plotting
import matplotlib
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import seaborn as sns
from ipywidgets import widgets
import plotly.express as px
import plotly.offline as pyo
import warnings
from matplotlib import pyplot
from scipy import stats
from functools import reduce

# %% [markdown]
# # Exploratory Analysis

# %%
def convert_google_csv_url(url):
    file_id=url.split('/')[-2]
    return 'https://drive.google.com/uc?id=' + file_id

# %%
url='https://drive.google.com/file/d/1HIFzmxgYgewmjC7b_85cfeYY0MUZ2pgT/view?usp=sharing'

energy_consumption_by_country = pd.read_csv(convert_google_csv_url(url))
energy_consumption_by_country.dataframeName = 'Percentage of Energy Consumption by Country.csv'
nRow, nCol = energy_consumption_by_country.shape
print(f'There are {nRow} rows and {nCol} columns')
energy_consumption_by_country.head(2)
# Out:
# There are 5190 rows and 11 columns
#    Entity Code  Year  Coal Consumption - EJ  Gas Consumption - EJ  \
# 0  Africa  NaN  1965               1.164586              0.034358
# 1  Africa  NaN  1966               1.163240              0.038412
#
#    Geo Biomass Other - TWh  Hydro Generation - TWh  Nuclear Generation - TWh  \
# 0                      0.0               13.905635                       0.0
# 1                      0.0               15.510004                       0.0
#
#    Solar Generation - TWh  Wind Generation -TWh  Oil Consumption - EJ
# 0                     0.0                   0.0              1.173241
# 1                     0.0                   0.0              1.284154

# %%
energy_consumption_by_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Entity                    5190 non-null   object
#  1   Code                      4145 non-null   object
#  2   Year                      5190 non-null   int64
#  3   Coal Consumption - EJ     5170 non-null   float64
#  4   Gas Consumption - EJ      5170 non-null   float64
#  5   Geo Biomass Other - TWh   5115 non-null   float64
#  6   Hydro Generation - TWh    5170 non-null   float64
#  7   Nuclear Generation - TWh  5170 non-null   float64
#  8   Solar Generation - TWh    5170 non-null   float64
#  9   Wind Generation -TWh      5170 non-null   float64
#  10  Oil Consumption - EJ      5184 non-null   float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 446.1+ KB

# %%
energy_cleaned = energy_consumption_by_country[energy_consumption_by_country.Year.between(2010,2020)].drop('Code', axis=1).dropna()
energy_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 980 entries, 45 to 5189
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Entity                    980 non-null    object
#  1   Year                      980 non-null    int64
#  2   Coal Consumption - EJ     980 non-null    float64
#  3   Gas Consumption - EJ      980 non-null    float64
#  4   Geo Biomass Other - TWh   980 non-null    float64
#  5   Hydro Generation - TWh    980 non-null    float64
#  6   Nuclear Generation - TWh  980 non-null    float64
#  7   Solar Generation - TWh    980 non-null    float64
#  8   Wind Generation -TWh      980 non-null    float64
#  9   Oil Consumption - EJ      980 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 84.2+ KB

# %%
url = 'https://drive.google.com/file/d/1kcIWPZGEnNTVjE35jyxRlEUhqPdjRfMp/view?usp=sharing'
co2_by_country = pd.read_csv(convert_google_csv_url(url))
co2_by_country.dataframeName = 'CO2 emissions by country.csv'
nRow, nCol = co2_by_country.shape
print(f'There are {nRow} rows and {nCol} columns')
co2_by_country.head(2)
# Out:
# There are 23372 rows and 4 columns
#         Entity Code  Year  Annual CO2 emissions
# 0  Afghanistan  AFG  1949              0.014656
# 1  Afghanistan  AFG  1950              0.084272

# %%
co2_by_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23372 entries, 0 to 23371
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entity                23372 non-null  object
#  1   Code                  19244 non-null  object
#  2   Year                  23372 non-null  int64
#  3   Annual CO2 emissions  23372 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 730.5+ KB

# %%
co2_cleaned = co2_by_country[co2_by_country.Year.between(2010,2020)].drop('Code', axis=1).dropna()
co2_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2139 entries, 61 to 23371
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entity                2139 non-null   object
#  1   Year                  2139 non-null   int64
#  2   Annual CO2 emissions  2139 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 66.8+ KB

# %%
url = 'https://drive.google.com/file/d/1CYkacxACEAGbBVy6CJZI9obIl0rt2suE/view?usp=sharing'
pollution_by_region = pd.read_csv(convert_google_csv_url(url))
pollution_by_region.dataframeName = 'Pollution emissions by region.csv'
nRow, nCol = pollution_by_region.shape
print(f'There are {nRow} rows and {nCol} columns')
pollution_by_region.head(2)
# Out:
# There are 10608 rows and 19 columns
#    TL Territory level and Typology REG_ID     Region      VAR  \
# 0   1                      Country    AUS  Australia  AIR_POL
# 1   1                      Country    AUS  Australia  AIR_POL
#
#                                            Indicator  POS     Position  TIME  \
# 0  Air Pollution in PM2.5 (average level in µg/m³...  ALL  All regions  2003
# 1  Air Pollution in PM2.5 (average level in µg/m³...  ALL  All regions  2006
#
#    Year  Unit Code  Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0  2003        NaN   NaN               0     Units                    NaN
# 1  2006        NaN   NaN               0     Units                    NaN
#
#    Reference Period  Value Flag Codes Flags
# 0               NaN  3.880        NaN   NaN
# 1               NaN  3.301        NaN   NaN

# %%
pollution_by_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10608 entries, 0 to 10607
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   TL                            10608 non-null  int64
#  1   Territory level and Typology  10608 non-null  object
#  2   REG_ID                        10608 non-null  object
#  3   Region                        10608 non-null  object
#  4   VAR                           10608 non-null  object
#  5   Indicator                     10608 non-null  object
#  6   POS                           10608 non-null  object
#  7   Position                      10608 non-null  object
#  8   TIME                          10608 non-null  int64
#  9   Year                          10608 non-null  int64
#  10  Unit Code                     0 non-null      float64
#  11  Unit                          0 non-null      float64
#  12  PowerCode Code                10608 non-null  int64
#  13  PowerCode                     10608 non-null  object
#  14  Reference Period Code         0 non-null      float64
#  15  Reference Period              0 non-null      float64
#  16  Value                         10608 non-null  float64
#  17  Flag Codes                    62 non-null     object
#  18  Flags                         62 non-null     object
# dtypes: float64(5), int64(4), object(10)
# memory usage: 1.5+ MB

# %%
url = 'https://drive.google.com/file/d/1YbQap_5e4vqKvCCWU8iB6tOByNttcNe2/view?usp=sharing'
deaths_by_particle_vs_pm25 = pd.read_csv(convert_google_csv_url(url))
deaths_by_particle_vs_pm25.dataframeName = 'Deaths by Particulate Matter Air Pollution vs PM25 by country.csv'
nRow, nCol = deaths_by_particle_vs_pm25.shape
print(f'There are {nRow} rows and {nCol} columns')
deaths_by_particle_vs_pm25.head(2)
# Out:
# There are 48331 rows and 7 columns
#         Entity      Code  Year  Total population (Gapminder, HYDE & UN)  \
# 0     Abkhazia  OWID_ABK  2015                                      NaN
# 1  Afghanistan       AFG  1800                                3280000.0
#
#   Continent  \
# 0      Asia
# 1       NaN
#
#    PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                                NaN
# 1                                                NaN
#
#    Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)
# 0                                                NaN
# 1                                                NaN

# %%
deaths_by_particle_vs_pm25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48331 entries, 0 to 48330
# Data columns (total 7 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Entity                                                                                    48331 non-null  object
#  1   Code                                                                                      46132 non-null  object
#  2   Year                                                                                      48331 non-null  int64
#  3   Total population (Gapminder, HYDE & UN)                                                   46883 non-null  float64
#  4   Continent                                                                                 285 non-null    object
#  5   PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)                    2640 non-null   float64
#  6   Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)  6468 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 2.6+ MB

# %%
deathspm25_cleaned = deaths_by_particle_vs_pm25[deaths_by_particle_vs_pm25.Year.between(2010,2020)].drop(['Code','Continent'], axis=1)
deathspm25_cleaned
# Out:
#               Entity  Year  Total population (Gapminder, HYDE & UN)  \
# 0           Abkhazia  2015                                      NaN
# 211      Afghanistan  2010                               29186000.0
# 212      Afghanistan  2011                               30117000.0
# 213      Afghanistan  2012                               31161000.0
# 214      Afghanistan  2013                               32270000.0
# ...              ...   ...                                      ...
# 48326       Zimbabwe  2016                               14030000.0
# 48327       Zimbabwe  2017                               14237000.0
# 48328       Zimbabwe  2018                               14439000.0
# 48329       Zimbabwe  2019                               14645000.0
# 48330  Åland Islands  2015                                      NaN
#
#        PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                                    NaN
# 211                                            46.536809
# 212                                            50.483960
# 213                                            50.653945
# 214                                            50.968831
# ...                                                  ...
# 48326                                          24.513035
# 48327                                                NaN
# 48328                                                NaN
# 48329                                                NaN
# 48330                                                NaN
#
#        Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)
# 0                                                    NaN
# 211                                            46.733269
# 212                                            48.290188
# 213                                            48.148226
# 214                                            46.376090
# ...                                                  ...
# 48326                                          25.643570
# 48327                                          26.166182
# 48328                                                NaN
# 48329                                                NaN
# 48330                                                NaN
#
# [3036 rows x 5 columns]

# %%
url = 'https://drive.google.com/file/d/1Qz92NhY8A2ILvTbMgYgTQQparjeE9ZPk/view?usp=sharing'
green_indicators = pd.read_csv(convert_google_csv_url(url))
green_indicators.dataframeName = 'Green Growth Indicators by country.csv'
nRow, nCol = green_indicators.shape
print(f'There are {nRow} rows and {nCol} columns')
green_indicators.head(2)
# Out:
# There are 160569 rows and 15 columns
#    COU    Country         VAR  \
# 0  AUS  Australia  CO2_PBPROD
# 1  AUS  Australia  CO2_PBPROD
#
#                                             Variable   YEA  Year Unit Code  \
# 0  Production-based CO2 productivity, GDP per uni...  1990  1990    USD_KG
# 1  Production-based CO2 productivity, GDP per uni...  1995  1995    USD_KG
#
#                       Unit  PowerCode Code PowerCode Reference Period Code  \
# 0  US dollars per kilogram               0     Units                  2015
# 1  US dollars per kilogram               0     Units                  2015
#
#   Reference Period     Value Flag Codes Flags
# 0             2015  1.964258        NaN   NaN
# 1             2015  2.094627        NaN   NaN

# %%
green_indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160569 entries, 0 to 160568
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   COU                    160569 non-null  object
#  1   Country                160569 non-null  object
#  2   VAR                    160569 non-null  object
#  3   Variable               160569 non-null  object
#  4   YEA                    160569 non-null  int64
#  5   Year                   160569 non-null  int64
#  6   Unit Code              160569 non-null  object
#  7   Unit                   160569 non-null  object
#  8   PowerCode Code         160569 non-null  int64
#  9   PowerCode              160569 non-null  object
#  10  Reference Period Code  22554 non-null   object
#  11  Reference Period       22554 non-null   object
#  12  Value                  160568 non-null  float64
#  13  Flag Codes             26212 non-null   object
#  14  Flags                  26212 non-null   object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 18.4+ MB

# %%
green_indic_cleaned = green_indicators[green_indicators.Year.between(2010,2020)].drop(['COU','Reference Period Code', 'Unit Code', 'VAR',
                                             'Reference Period', 'Flag Codes', 'Flags', 'YEA', 'PowerCode', 'PowerCode Code','Unit'],axis=1).dropna()
green_indic_cleaned = green_indic_cleaned[green_indic_cleaned.Variable == 'Renewable electricity, % total electricity generation'].drop('Variable',axis=1)
green_indic_cleaned.columns = ['Entity','Year','%RenewableElectricity']
green_indic_cleaned
# Out:
#               Entity  Year  %RenewableElectricity
# 69         Australia  2010               8.598495
# 70         Australia  2011              10.355690
# 71         Australia  2012              10.492490
# 72         Australia  2013              13.122810
# 73         Australia  2014              14.598490
# ...              ...   ...                    ...
# 145232  South Sudan   2013               0.423729
# 145233  South Sudan   2014               0.408163
# 145234  South Sudan   2015               0.346021
# 145235  South Sudan   2016               0.330033
# 145236  South Sudan   2017               0.553505
#
# [1264 rows x 3 columns]

# %%
green_indic_cleaned.head(1)
# Out:
#        Entity  Year  %RenewableElectricity
# 69  Australia  2010               8.598495

# %%
energy_co2 = pd.merge(energy_cleaned, co2_cleaned,  how='left', left_on=['Entity','Year'], right_on = ['Entity','Year'])
energy_co2_death = pd.merge(energy_co2, deathspm25_cleaned,  how='left', left_on=['Entity','Year'], right_on = ['Entity','Year'])
energy_co2_death_green = pd.merge(energy_co2_death, green_indic_cleaned,  how='left', left_on=['Entity','Year'], right_on = ['Entity','Year'])
energy_co2_death_green.columns = ['Country', 'Year', 'Coal', 'Gas', 'Biomass','Hydro','Nuclear','Solar','Wind','Oil','CO2',
                                  'Population','PM2.5','Deaths','%RenewableElectricity']
energy_co2_death_green.shape
# Out:
# (980, 15)

# %%
energy_co2_death_green.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 980 entries, 0 to 979
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                980 non-null    object
#  1   Year                   980 non-null    int64
#  2   Coal                   980 non-null    float64
#  3   Gas                    980 non-null    float64
#  4   Biomass                980 non-null    float64
#  5   Hydro                  980 non-null    float64
#  6   Nuclear                980 non-null    float64
#  7   Solar                  980 non-null    float64
#  8   Wind                   980 non-null    float64
#  9   Oil                    980 non-null    float64
#  10  CO2                    747 non-null    float64
#  11  Population             830 non-null    float64
#  12  PM2.5                  553 non-null    float64
#  13  Deaths                 640 non-null    float64
#  14  %RenewableElectricity  636 non-null    float64
# dtypes: float64(13), int64(1), object(1)
# memory usage: 122.5+ KB

# %%
energy_co2_death_green.head(1)
# Out:
#   Country  Year      Coal       Gas   Biomass       Hydro  Nuclear     Solar  \
# 0  Africa  2010  4.190915  3.561004  3.829542  107.426833   13.527  0.213821
#
#        Wind       Oil          CO2    Population  PM2.5  Deaths  \
# 0  2.284182  7.127722  1220.494175  1.039304e+09    NaN     NaN
#
#    %RenewableElectricity
# 0                    NaN

# %%
energy_co2_death_green.iloc[:,1:]
# Out:
#      Year        Coal         Gas     Biomass        Hydro      Nuclear  \
# 0    2010    4.190915    3.561004    3.829542   107.426833    13.527000
# 1    2011    4.120680    3.859500    3.929657   110.444821    12.902000
# 2    2012    4.017909    4.143867    4.089950   110.952300    12.967434
# 3    2013    4.070297    4.198677    4.438768   117.672846    14.105998
# 4    2014    4.264064    4.316121    5.552723   123.726795    13.794000
# ..    ...         ...         ...         ...          ...          ...
# 975  2015  157.838896  125.208334  538.277477  3884.619692  2575.763561
# 976  2016  155.504177  128.124027  547.865908  4012.947981  2614.905286
# 977  2017  156.094106  131.708206  582.893132  4065.869592  2638.554157
# 978  2018  158.793935  138.659832  615.038237  4171.404951  2700.373917
# 979  2019  157.857047  141.452770  651.811211  4222.214992  2795.961529
#
#           Solar         Wind         Oil           CO2    Population  \
# 0      0.213821     2.284182    7.127722   1220.494175  1.039304e+09
# 1      0.452785     2.537473    6.934442   1250.925424  1.066410e+09
# 2      0.551142     2.961731    7.311970   1260.971595  1.094343e+09
# 3      0.824348     3.559784    7.573096   1277.276337  1.123045e+09
# 4      1.831308     5.158122    7.699942   1365.297815  1.152434e+09
# ..          ...          ...         ...           ...           ...
# 975  256.838045   831.567440  183.210968  35462.746740  7.379797e+09
# 976  328.237428   963.774036  186.912413  35675.099440  7.464022e+09
# 977  446.946764  1140.971268  189.242920  36153.261650  7.547859e+09
# 978  582.754345  1270.164880  191.451896  36572.754220  7.631091e+09
# 979  724.086506  1429.619982  193.031574           NaN  7.713468e+09
#
#          PM2.5     Deaths  %RenewableElectricity
# 0          NaN        NaN                    NaN
# 1          NaN        NaN                    NaN
# 2          NaN        NaN                    NaN
# 3          NaN        NaN                    NaN
# 4          NaN        NaN                    NaN
# ..         ...        ...                    ...
# 975  49.104505  39.493979               22.77481
# 976  49.673465  38.203701               23.74566
# 977        NaN  38.154357               24.48415
# 978        NaN        NaN                    NaN
# 979        NaN        NaN                    NaN
#
# [980 rows x 14 columns]

# %% [markdown]
# # Is there a link between Deaths and PM2.5 Air pollution ? Let's check with a ttest_ind

# %%
stats.ttest_ind(deathspm25_cleaned['Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)'].dropna(), deathspm25_cleaned['PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)'].dropna())
# pvalue > 5% So we can not reject the independance of PM2.5 and Deaths variables
# I used full database with more values to get a more accurate result
# Out:
# Ttest_indResult(statistic=0.4816112333761088, pvalue=0.6301120330029324)

# %% [markdown]
# # I Think the more PM2.5 we have the more Deaths we have.
# # I think over the years Solar, Wind and Biomass have increased
# ## Let's find correlations between all these values

# %%
corr = energy_co2_death_green.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col0,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col1,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col2,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow3_col3,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow4_col4,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow5_col5,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow6_col6,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow7_col7,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow8_col8,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow9_col9,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow10_col10,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow11_col11,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow12_col12,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col1,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col10{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col2,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col3,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow11_col13{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col4,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow13_col7{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col5,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col8,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow11_col6,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow12_col8{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col6,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow7_col0{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col7,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow11_col9,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow12_col10{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col9,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow11_col3,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow11_col7{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col11,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col11,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow3_col12,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow4_col11,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow6_col12,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow6_col13{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col12{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow0_col13{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col0,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow12_col9{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col2{
#             background-color:  #e8765c;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col3,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow3_col1{
#             background-color:  #e36c55;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col4{
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col5,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow6_col8,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow11_col12{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col6{
#             background-color:  #f6a283;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col7{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col8,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow8_col1{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col9,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow9_col1{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col10,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow10_col1{
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col11{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col12{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow1_col13{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col0,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow4_col0,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow11_col8{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col1{
#             background-color:  #e9785d;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col3,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow3_col2,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow3_col5,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow5_col3{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col4{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col5,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow3_col4,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow4_col3,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow5_col2{
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col6{
#             background-color:  #f39778;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col7,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow4_col5,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow5_col7{
#             background-color:  #d95847;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col8,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow8_col2{
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col9,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow9_col2{
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col10,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow4_col1,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow4_col2,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow5_col9,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow9_col5,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow10_col2{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col12{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow2_col13{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow3_col0,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow11_col0{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow3_col6,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow6_col3,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow10_col7{
#             background-color:  #e36b54;
#             color:  #000000;
#         }#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow3_col7,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow3_col9,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow7_col3,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow8_col10,#T_9c4e9b38_ca89_11eb_bf26_efc8ec119b6erow9_col3,#T_9c4e9b38_ca89_11eb_bf26_ef

# %%
ax = sns.pairplot(energy_co2_death_green, corner=True)

# %%
#Remove the world first line to get comprehensive data
energy_grouped = energy_co2_death_green.groupby(['Country']).mean().sort_values(by='Coal', ascending=False).iloc[1:].drop(['Year'], axis=1)
energy_grouped.describe()
# Out:
#              Coal        Gas     Biomass        Hydro     Nuclear       Solar  \
# count   97.000000  97.000000   97.000000    97.000000   97.000000   97.000000
# mean     3.254890   2.591925   10.536409    79.694082   54.128021    5.928202
# std     14.289989   5.950045   28.553973   216.894981  172.206953   18.971040
# min      0.000000   0.000000    0.000000     0.000000    0.000000    0.000000
# 25%      0.033946   0.147199    0.095191     1.880824    0.000000    0.040333
# 50%      0.169420   0.598940    0.718307    13.175123    0.000000    0.335462
# 75%      0.738032   1.630479    5.999826    39.890692   15.678088    1.969107
# max    114.366412  33.044537  184.214017  1473.997665  974.460635  129.646415
#
#              Wind        Oil          CO2    Population       PM2.5  \
# count   97.000000  97.000000    82.000000  8.200000e+01   78.000000
# mean    17.102061   3.761448   569.524938  1.007051e+08   28.068272
# std     53.612043   9.331893  1527.818505  2.556304e+08   27.626477
# min      0.000000   0.035847     3.534221  3.297000e+05    5.391961
# 25%      0.044234   0.393626    45.829041  6.047725e+06   12.793364
# 50%      0.676663   0.805876   101.618631  2.216615e+07   18.516193
# 75%      5.682896   2.642925   367.145652  6.524380e+07   27.853889
# max    295.787467  63.921412  9607.101765  1.402420e+09  144.272121
#
#            Deaths  %RenewableElectricity
# count   79.000000              72.000000
# mean    33.571778              26.917775
# std     20.135243              25.648881
# min      9.141243               0.000000
# 25%     17.755958               9.223999
# 50%     30.139523              15.805957
# 75%     44.891238              41.377170
# max    108.833189              99.983584

# %%
energy_grouped['Nuclear'].hist()
# Out:
# <AxesSubplot:>

# %%
energy_grouped['Solar'].hist()
# Out:
# <AxesSubplot:>

# %%
fig, ax = pyplot.subplots(figsize=(15,8))
ax = sns.heatmap(energy_grouped.iloc[:,0:2].head(10))

# %%
fig, ax = pyplot.subplots(figsize=(15,8))
ax = sns.heatmap(energy_grouped.iloc[:,2:7].head(10))

# %%
ebc_light = energy_co2_death_green[(energy_co2_death_green.Country == 'Iceland') | (energy_co2_death_green.Country == 'France') | (energy_co2_death_green.Country == 'Australia')]
ebc_light.head()
# Out:
#       Country  Year      Coal       Gas   Biomass   Hydro  Nuclear     Solar  \
# 40  Australia  2010  2.186381  1.216211  2.441550  13.746      0.0  0.977648
# 41  Australia  2011  2.131171  1.270191  2.573950  19.572      0.0  2.044547
# 42  Australia  2012  1.995833  1.274064  3.097850  17.036      0.0  2.412000
# 43  Australia  2013  1.894233  1.338245  3.331650  19.089      0.0  3.847400
# 44  Australia  2014  1.878550  1.443597  3.546362  14.484      0.0  4.952000
#
#      Wind       Oil         CO2  Population     PM2.5     Deaths  \
# 40  4.985  1.818086  406.425942  22155000.0  5.937561  13.140380
# 41  6.432  1.936222  404.263695  22538000.0  5.880919  13.276676
# 42  7.725  2.011291  406.986985  22904000.0  5.981776  12.196401
# 43  9.259  2.047592  398.051591  23255000.0  6.028238  11.384154
# 44  9.777  2.069432  393.288532  23596000.0  5.933055  10.939491
#
#     %RenewableElectricity
# 40               8.598495
# 41              10.355690
# 42              10.492490
# 43              13.122810
# 44              14.598490

# %%
sns.lineplot(data=ebc_light, x="Year", y="Coal", hue="Country", color='g').set_title('Coal Consumption - EJ and Solar Generation TWh (transparent)')
ax2 = plt.twinx()
sns.lineplot(data=ebc_light, x="Year", y="Solar", hue="Country", color='b', alpha=0.5, ax=ax2)
# Out:
# <AxesSubplot:label='cf3eb31c-ffe0-4bdd-9534-a6906e4e2693', xlabel='Year', ylabel='Solar'>

# %%
co2_by_country_light = co2_by_country[(co2_by_country.Entity == 'Iceland') | (co2_by_country.Entity == 'France') | (co2_by_country.Entity == 'Australia')]
co2_by_country_light.head()
# Out:
#          Entity Code  Year  Annual CO2 emissions
# 1531  Australia  AUS  1851             -0.062288
# 1532  Australia  AUS  1852             -0.054960
# 1533  Australia  AUS  1853             -0.109920
# 1534  Australia  AUS  1854             -0.128240
# 1535  Australia  AUS  1855             -0.131904

# %%
sns.lineplot(data=co2_by_country_light, x="Year", y="Annual CO2 emissions", hue="Entity").set_title('Annual CO2 emissions by country')
# Out:
# Text(0.5, 1.0, 'Annual CO2 emissions by country')

# %%
co2_grouped = co2_by_country.groupby(['Entity']).mean().drop(['Year'], axis=1).reset_index().sort_values(by='Annual CO2 emissions', ascending=False)
co2_grouped
# Out:
#                         Entity  Annual CO2 emissions
# 114                 KP Annex B          12721.770477
# 170                       OECD          11192.793896
# 165                   Non-OECD          10328.615514
# 164             Non KP Annex B           8799.638933
# 246                      World           6014.242731
# ..                         ...                   ...
# 245  Wallis and Futuna Islands              0.025357
# 232                     Tuvalu              0.009128
# 189               Saint Helena              0.009120
# 7          Antarctic Fisheries              0.007328
# 163                       Niue              0.005396
#
# [252 rows x 2 columns]

# %%
sns.set_theme(style="whitegrid")
fig, ax = pyplot.subplots(figsize=(15,8))
ax = sns.barplot(x="Entity", y="Annual CO2 emissions",data=co2_grouped.iloc[5:10])

# %%
pollution_by_country = pollution_by_region[(pollution_by_region.VAR == 'AIR_POL') & (pollution_by_region['Territory level and Typology'] == 'Country')]
pollution_by_country.head()
# Out:
#     TL Territory level and Typology REG_ID     Region      VAR  \
# 0    1                      Country    AUS  Australia  AIR_POL
# 1    1                      Country    AUS  Australia  AIR_POL
# 4    1                      Country    AUS  Australia  AIR_POL
# 5    1                      Country    AUS  Australia  AIR_POL
# 54   1                      Country    AUT    Austria  AIR_POL
#
#                                             Indicator  POS     Position  TIME  \
# 0   Air Pollution in PM2.5 (average level in µg/m³...  ALL  All regions  2003
# 1   Air Pollution in PM2.5 (average level in µg/m³...  ALL  All regions  2006
# 4   Air Pollution in PM2.5 (average level in µg/m³...  ALL  All regions  2009
# 5   Air Pollution in PM2.5 (average level in µg/m³...  ALL  All regions  2012
# 54  Air Pollution in PM2.5 (average level in µg/m³...  ALL  All regions  2003
#
#     Year  Unit Code  Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0   2003        NaN   NaN               0     Units                    NaN
# 1   2006        NaN   NaN               0     Units                    NaN
# 4   2009        NaN   NaN               0     Units                    NaN
# 5   2012        NaN   NaN               0     Units                    NaN
# 54  2003        NaN   NaN               0     Units                    NaN
#
#     Reference Period   Value Flag Codes Flags
# 0                NaN   3.880        NaN   NaN
# 1                NaN   3.301        NaN   NaN
# 4                NaN   3.594        NaN   NaN
# 5                NaN   7.000        NaN   NaN
# 54               NaN  19.677        NaN   NaN

# %%
pollution_by_countrylight = pollution_by_country[(pollution_by_country.Region == 'Iceland') | (pollution_by_country.Region == 'France') | (pollution_by_country.Region == 'Australia')]
fig, ax = pyplot.subplots(figsize=(15,8))
sns.barplot(data=pollution_by_countrylight, x="Year", y="Value", hue="Region").set_title('CO2 Emissions in ug/m3')
# Out:
# Text(0.5, 1.0, 'CO2 Emissions in ug/m3')

# %%
deaths_grouped = deaths_by_particle_vs_pm25.drop(['Continent','Year'], axis=1).groupby('Entity').mean().dropna().reset_index()
deaths_grouped
# Out:
#              Entity  Total population (Gapminder, HYDE & UN)  \
# 0       Afghanistan                             8.546004e+06
# 1           Albania                             1.283899e+06
# 2           Algeria                             1.038665e+07
# 3    American Samoa                             3.978571e+04
# 4           Andorra                             1.713222e+04
# ..              ...                                      ...
# 190         Vietnam                             2.776956e+07
# 191           World                             3.004868e+09
# 192           Yemen                             6.072310e+06
# 193          Zambia                             3.088306e+06
# 194        Zimbabwe                             3.857202e+06
#
#      PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                            53.546737
# 1                                            15.058675
# 2                                            31.712808
# 3                                             3.809215
# 4                                            11.110804
# ..                                                 ...
# 190                                          27.260872
# 191                                          42.944725
# 192                                          57.460539
# 193                                          29.031042
# 194                                          24.204219
#
#      Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)
# 0                                            45.979634
# 1                                            22.319736
# 2                                            50.522883
# 3                                            37.743906
# 4                                            18.356823
# ..                                                 ...
# 190                                          28.866898
# 191                                          42.369640
# 192                                          44.368401
# 193                                          24.739512
# 194                                          26.643354
#
# [195 rows x 4 columns]

# %%
dbppm25 = deaths_by_particle_vs_pm25[(deaths_by_particle_vs_pm25.Entity == 'Iceland') | (deaths_by_particle_vs_pm25.Entity == 'France') | (deaths_by_particle_vs_pm25.Entity == 'Australia')]
sns.lineplot(data=dbppm25, x="Year", y="Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)", hue="Entity").set_title('Death by PM25 Particles')
sns.lineplot(data=dbppm25, x="Year", y="PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)", hue="Entity").set_title('Death by PM25 Particles')
# Out:
# Text(0.5, 1.0, 'Death by PM25 Particles')

# %%
pm25Vdeath = deaths_by_particle_vs_pm25.sort_values(by=['PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)'], ascending=False).dropna().head(None)
pm25Vdeath = pm25Vdeath[pm25Vdeath.Year.between(2010,2020,inclusive=True)]
pm25Vdeath = pm25Vdeath.rename(columns={"Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)":"Deaths - Ambient particulate matter pollution"})
pm25Vdeath = pm25Vdeath.rename(columns={"Total population (Gapminder, HYDE & UN)":"Total population"})
pm25Vdeath = pm25Vdeath.rename(columns={"PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)": "PM2.5 air pollution (μg per cm3)"})

sns.scatterplot(
    data=pm25Vdeath, x="Deaths - Ambient particulate matter pollution", y="PM2.5 air pollution (μg per cm3)", hue="Entity", size="Total population",
    sizes=(20, 200), legend=False
)
# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# No handles with labels found to put in legend.

# %%
pm25Vdeath.sort_values(by=['PM2.5 air pollution (μg per cm3)'], ascending=False)
# Out:
#                Entity Code  Year  Total population      Continent  \
# 30820           Niger  NER  2015        20002000.0         Africa
# 37241    Saudi Arabia  SAU  2015        31718000.0           Asia
# 34689           Qatar  QAT  2015         2566000.0           Asia
# 7334         Cameroon  CMR  2015        23298000.0         Africa
# 12776           Egypt  EGY  2015        92443000.0         Africa
# ...               ...  ...   ...               ...            ...
# 16494       Greenland  GRL  2015           56000.0  North America
# 21959        Kiribati  KIR  2015          111000.0        Oceania
# 43579           Tonga  TON  2015          101000.0        Oceania
# 36581           Samoa  WSM  2015          194000.0        Oceania
# 849    American Samoa  ASM  2015           56000.0        Oceania
#
#        PM2.5 air pollution (μg per cm3)  \
# 30820                        190.884126
# 37241                        182.921456
# 34689                        147.535340
# 7334                         134.793750
# 12776                        124.875127
# ...                                 ...
# 16494                          4.119724
# 21959                          4.050094
# 43579                          4.016893
# 36581                          3.851702
# 849                            3.790379
#
#        Deaths - Ambient particulate matter pollution
# 30820                                      26.257089
# 37241                                      67.274180
# 34689                                      63.209003
# 7334                                       55.991541
# 12776                                     111.062806
# ...                                              ...
# 16494                                      30.296216
# 21959                                      15.872468
# 43579                                      25.023758
# 36581                                      16.740490
# 849                                        39.226430
#
# [193 rows x 7 columns]

# %%
pm25Vdeath.sort_values(by=['Deaths - Ambient particulate matter pollution'], ascending=False)
# Out:
#                      Entity Code  Year  Total population Continent  \
# 12776                 Egypt  EGY  2015      9.244300e+07    Africa
# 46404            Uzbekistan  UZB  2015      3.093000e+07      Asia
# 45441  United Arab Emirates  ARE  2015      9.263000e+06      Asia
# 19248                 India  IND  2015      1.310152e+09      Asia
# 23925                 Libya  LBY  2015      6.418000e+06    Africa
# ...                     ...  ...   ...               ...       ...
# 31800                Norway  NOR  2015      5.200000e+06    Europe
# 19028               Iceland  ISL  2015      3.300000e+05    Europe
# 30380           New Zealand  NZL  2015      4.615000e+06   Oceania
# 41518                Sweden  SWE  2015      9.765000e+06    Europe
# 14662               Finland  FIN  2015      5.481000e+06    Europe
#
#        PM2.5 air pollution (μg per cm3)  \
# 12776                        124.875127
# 46404                         46.213010
# 45441                        102.926240
# 19248                         75.582857
# 23925                         64.425729
# ...                                 ...
# 31800                          7.913174
# 19028                          7.328428
# 30380                          5.533858
# 41518                          5.222488
# 14662                          6.277478
#
#        Deaths - Ambient particulate matter pollution
# 12776                                     111.062806
# 46404                                      83.218565
# 45441                                      75.215920
# 19248                                      69.485160
# 23925                                      68.159076
# ...                                              ...
# 31800                                       9.710341
# 19028                                       9.169528
# 30380                                       9.040563
# 41518                                       8.477785
# 14662                                       7.840072
#
# [193 rows x 7 columns]

# %%
green_indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160569 entries, 0 to 160568
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   COU                    160569 non-null  object
#  1   Country                160569 non-null  object
#  2   VAR                    160569 non-null  object
#  3   Variable               160569 non-null  object
#  4   YEA                    160569 non-null  int64
#  5   Year                   160569 non-null  int64
#  6   Unit Code              160569 non-null  object
#  7   Unit                   160569 non-null  object
#  8   PowerCode Code         160569 non-null  int64
#  9   PowerCode              160569 non-null  object
#  10  Reference Period Code  22554 non-null   object
#  11  Reference Period       22554 non-null   object
#  12  Value                  160568 non-null  float64
#  13  Flag Codes             26212 non-null   object
#  14  Flags                  26212 non-null   object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 18.4+ MB

# %%
#green_indicators.Variable.unique()
green_indicators.Unit.unique()
# Out:
# array(['US dollars per kilogram', 'Tonnes', 'US Dollar',
#        'Tonnes of oil equivalent (toe)', 'Percentage',
#        'Cubic metres per capita', 'Number', 'Inhabitants', 'Ratio',
#        'US dollars per litre', 'Index', 'Kilograms per capita',
#        'Percentage points', 'Micrograms per cubic metre',
#        'Per 1 000 000 inhabitants', 'Kilograms', 'Cubic metres',
#        'Square metres', 'Children', 'Years', 'Per 1 000 inhabitants',
#        'Square kilometres'], dtype=object)

# %%
percent_renewable_energy_supply = green_indicators[green_indicators.Variable == 'Renewable energy supply, % total energy supply']
percent_renewable_energy_supply.sort_values('Value', ascending=False)
# Out:
#        COU               Country      VAR  \
# 42137  PRY              Paraguay  RE_TPES
# 42138  PRY              Paraguay  RE_TPES
# 42136  PRY              Paraguay  RE_TPES
# 42141  PRY              Paraguay  RE_TPES
# 42135  PRY              Paraguay  RE_TPES
# ...    ...                   ...      ...
# 43124  ARE  United Arab Emirates  RE_TPES
# 44290  BHR               Bahrain  RE_TPES
# 44291  BHR               Bahrain  RE_TPES
# 44292  BHR               Bahrain  RE_TPES
# 45421  OMN                  Oman  RE_TPES
#
#                                              Variable   YEA  Year Unit Code  \
# 42137  Renewable energy supply, % total energy supply  2000  2000        PC
# 42138  Renewable energy supply, % total energy supply  2005  2005        PC
# 42136  Renewable energy supply, % total energy supply  1995  1995        PC
# 42141  Renewable energy supply, % total energy supply  2012  2012        PC
# 42135  Renewable energy supply, % total energy supply  1990  1990        PC
# ...                                               ...   ...   ...       ...
# 43124  Renewable energy supply, % total energy supply  1990  1990        PC
# 44290  Renewable energy supply, % total energy supply  1990  1990        PC
# 44291  Renewable energy supply, % total energy supply  1995  1995        PC
# 44292  Renewable energy supply, % total energy supply  2000  2000        PC
# 45421  Renewable energy supply, % total energy supply  2013  2013        PC
#
#              Unit  PowerCode Code PowerCode Reference Period Code  \
# 42137  Percentage               0     Units                   NaN
# 42138  Percentage               0     Units                   NaN
# 42136  Percentage               0     Units                   NaN
# 42141  Percentage               0     Units                   NaN
# 42135  Percentage               0     Units                   NaN
# ...           ...             ...       ...                   ...
# 43124  Percentage               0     Units                   NaN
# 44290  Percentage               0     Units                   NaN
# 44291  Percentage               0     Units                   NaN
# 44292  Percentage               0     Units                   NaN
# 45421  Percentage               0     Units                   NaN
#
#       Reference Period     Value Flag Codes Flags
# 42137              NaN  177.1503        NaN   NaN
# 42138              NaN  165.8764        NaN   NaN
# 42136              NaN  153.4931        NaN   NaN
# 42141              NaN  149.7069        NaN   NaN
# 42135              NaN  148.5519        NaN   NaN
# ...                ...       ...        ...   ...
# 43124              NaN    0.0000        NaN   NaN
# 44290              NaN    0.0000        NaN   NaN
# 44291              NaN    0.0000        NaN   NaN
# 44292              NaN    0.0000        NaN   NaN
# 45421              NaN    0.0000        NaN   NaN
#
# [1840 rows x 15 columns]

# %%
renewable = percent_renewable_energy_supply[(percent_renewable_energy_supply.Country == 'Iceland') | (percent_renewable_energy_supply.Country == 'France') | (percent_renewable_energy_supply.Country == 'Australia')]
sns.lineplot(data=renewable, x="Year", y="Value", hue="Country").set_title('% Renewable energy by country')
# Out:
# Text(0.5, 1.0, '% Renewable energy by country')

# %%
mean_percent = percent_renewable_energy_supply.groupby('Country').mean().sort_values('Value', ascending = False).drop(['YEA','Year','PowerCode Code'], axis = 1)
mean_percent
# Out:
#                                        Value
# Country
# Paraguay                          142.283754
# Democratic Republic of the Congo   96.177789
# Ethiopia                           93.494862
# Zambia                             89.908198
# Mozambique                         89.382563
# ...                                      ...
# Kuwait                              0.009431
# Saudi Arabia                        0.007488
# Qatar                               0.000000
# Oman                                0.000000
# Bahrain                             0.000000
#
# [148 rows x 1 columns]

# %%
sns.histplot(data=mean_percent, binwidth=3, kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=mean_percent.Value)

# %%
df = green_indicators[green_indicators.Variable == 'Welfare costs of premature mortalities from exposure to ambient PM2.5, GDP equivalent']
premature_mortalities_pm25 = df[(df.Country == 'Iceland') | (df.Country == 'France') | (df.Country == 'Australia')]
sns.lineplot(data=premature_mortalities_pm25, x="Year", y="Value", hue="Country").set_title('Premature mortalities by pm25 cost')
# Out:
# Text(0.5, 1.0, 'Premature mortalities by pm25 cost')

# %%
fossil_fuel_prices = pd.read_csv("./Environment-Equity Datasets/Corporations/Fossil Fuel Prices (1989-2019).csv")
fossil_fuel_prices.dataframeName = 'Fossil Fuel Prices (1989-2019)'
nRow, nCol = fossil_fuel_prices.shape
print(f'There are {nRow} rows and {nCol} columns')
fossil_fuel_prices.head()
# Out:
# There are 31 rows and 5 columns
#    Year  Crude Oil/US dollars per barrel  \
# 0  1989                            18.23
# 1  1990                            23.73
# 2  1991                            20.00
# 3  1992                            19.32
# 4  1993                            16.97
#
#    Natural Gas (Henry Hub)/US dollars per million Btu  \
# 0                                               1.70
# 1                                               1.64
# 2                                               1.49
# 3                                               1.77
# 4                                               2.12
#
#    Coal (Northwest Europe Marker Price)/US dollars per tonne  Unnamed: 4
# 0                                              42.08                 NaN
# 1                                              43.48                 NaN
# 2                                              42.80                 NaN
# 3                                              38.53                 NaN
# 4                                              33.68                 NaN

# %%
fossil_fuel_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Year                                                       31 non-null     int64
#  1   Crude Oil/US dollars per barrel                            31 non-null     float64
#  2   Natural Gas (Henry Hub)/US dollars per million Btu         31 non-null     float64
#  3   Coal (Northwest Europe Marker Price)/US dollars per tonne  31 non-null     float64
#  4   Unnamed: 4                                                 0 non-null      float64
# dtypes: float64(4), int64(1)
# memory usage: 1.3 KB

# %%
fossil_fuel_prices_2010to2019 = fossil_fuel_prices[fossil_fuel_prices.Year.between(2010,2020)]

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(fossil_fuel_prices_2010to2019.Year, fossil_fuel_prices_2010to2019['Coal (Northwest Europe Marker Price)/US dollars per tonne'])
ax2.plot(fossil_fuel_prices_2010to2019.Year, energy_co2_death_green[energy_co2_death_green.Country == 'World']['%RenewableElectricity'], 'o-', color="red" )

ax1.set_xlabel('X data')
ax1.set_ylabel('Coal Price / Tonne', color='b')
ax2.set_ylabel('Renewable Energy (MW)', color='r')

plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
plotScatterMatrix(green_indicators, 10, 10)
